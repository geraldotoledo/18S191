# %%
# %matplotlib inline

# %%
# !pip install nni
# Out:
# Requirement already satisfied: nni in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: astor in /usr/local/lib/python3.12/dist-packages (from nni) (0.8.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from nni) (3.1.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from nni) (0.4.6)
# Requirement already satisfied: filelock<3.12 in /usr/local/lib/python3.12/dist-packages (from nni) (3.11.0)
# Requirement already satisfied: json-tricks>=3.15.5 in /usr/local/lib/python3.12/dist-packages (from nni) (3.17.3)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from nni) (12.575.51)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nni) (25.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from nni) (2.2.2)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from nni) (3.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from nni) (5.9.5)
# Requirement already satisfied: PythonWebHDFS in /usr/local/lib/python3.12/dist-packages (from nni) (0.2.3)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.12/dist-packages (from nni) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nni) (2.32.4)
# Requirement already satisfied: responses in /usr/local/lib/python3.12/dist-packages (from nni) (0.25.8)
# Requirement already satisfied: schema in /usr/local/lib/python3.12/dist-packages (from nni) (0.7.7)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from nni) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nni) (4.67.1)
# Requirement already satisfied: typeguard<4.1.3,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from nni) (4.1.2)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from nni) (4.14.1)
# Requirement already satisfied: websockets>=10.1 in /usr/local/lib/python3.12/dist-packages (from nni) (15.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from nni) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from nni) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->nni) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->nni) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->nni) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->nni) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->nni) (2025.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->nni) (0.2.13)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from PythonWebHDFS->nni) (3.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nni) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nni) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nni) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nni) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->nni) (1.17.0)

# %% [markdown]
# # Port PyTorch Quickstart to NNI
# This is a modified version of `PyTorch quickstart`_.
#
# It can be run directly and will have the exact same result as original version.
#
# Furthermore, it enables the ability of auto tuning with an NNI *experiment*, which will be detailed later.
#
# It is recommended to run this script directly first to verify the environment.
#
# There are 2 key differences from the original version:
#
# 1. In `Get optimized hyperparameters`_ part, it receives generated hyperparameters.
# 2. In `Train model and report accuracy`_ part, it reports accuracy metrics to NNI.

# %%
import nni
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %% [markdown]
# ## Hyperparameters to be tuned
# These are the hyperparameters that will be tuned.

# %%
params = {
    'features': 512,
    'lr': 0.001,
    'momentum': 0,
}

# %% [markdown]
# ## Get optimized hyperparameters
# If run directly, :func:`nni.get_next_parameter` is a no-op and returns an empty dict.
# But with an NNI *experiment*, it will receive optimized hyperparameters from tuning algorithm.

# %%
optimized_params = nni.get_next_parameter()
params.update(optimized_params)
print(params)
# Out:
# {'features': 512, 'lr': 0.001, 'momentum': 0}
# /usr/local/lib/python3.12/dist-packages/nni/runtime/trial_command_channel/standalone.py:34: RuntimeWarning: Running trial code without runtime. Please check the tutorial if you are new to NNI: https://nni.readthedocs.io/en/stable/tutorials/hpo_quickstart_pytorch/main.html
#   warnings.warn(warning_message, RuntimeWarning)

# %% [markdown]
# ## Load dataset

# %%
training_data = datasets.FashionMNIST(root="data", train=True, download=True, transform=ToTensor())
test_data = datasets.FashionMNIST(root="data", train=False, download=True, transform=ToTensor())

batch_size = 64

train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)
# Out:
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 17.4MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 308kB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 5.51MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 19.3MB/s]

# %% [markdown]
# ## Build model with hyperparameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, params['features']),
            nn.ReLU(),
            nn.Linear(params['features'], params['features']),
            nn.ReLU(),
            nn.Linear(params['features'], 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=params['lr'], momentum=params['momentum'])
# Out:
# Using cpu device

# %% [markdown]
# ## Define train and test

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        pred = model(X)
        loss = loss_fn(pred, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    return correct

# %% [markdown]
# ## Train model and report accuracy
# Report accuracy metrics to NNI so the tuning algorithm can suggest better hyperparameters.

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    accuracy = test(test_dataloader, model, loss_fn)
    nni.report_intermediate_result(accuracy)
nni.report_final_result(accuracy)
# Out:
# Epoch 1
# -------------------------------
# [2025-08-22 03:51:05] Intermediate result: 0.5104  (Index 0)
# INFO:nni:Intermediate result: 0.5104  (Index 0)
# Epoch 2
# -------------------------------
# [2025-08-22 03:51:21] Intermediate result: 0.6066  (Index 1)
# INFO:nni:Intermediate result: 0.6066  (Index 1)
# Epoch 3
# -------------------------------
# [2025-08-22 03:51:36] Intermediate result: 0.6185  (Index 2)
# INFO:nni:Intermediate result: 0.6185  (Index 2)
# Epoch 4
# -------------------------------
# [2025-08-22 03:51:51] Intermediate result: 0.631  (Index 3)
# INFO:nni:Intermediate result: 0.631  (Index 3)
# Epoch 5
# -------------------------------
# [2025-08-22 03:52:06] Intermediate result: 0.6447  (Index 4)
# INFO:nni:Intermediate result: 0.6447  (Index 4)
# [2025-08-22 03:52:06] Final result: 0.6447
# INFO:nni:Final result: 0.6447
